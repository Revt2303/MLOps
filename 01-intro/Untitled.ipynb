# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
df = pd.read_parquet()

# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 53.7 MB/s eta 0:00:000m eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
